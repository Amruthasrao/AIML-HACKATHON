# %% [markdown]
# <a href="https://colab.research.google.com/github/Amruthasrao/AIML-HACKATHON/blob/main/heartdisease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/processed.cleveland.data")
df
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num
# 0      3.0  0.0  6.0    0
# ...

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope         num
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.937294
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    float64
#  1   sex       303 non-null    float64
#  2   cp        303 non-null    float64
#  3   trestbps  303 non-null    float64
#  4   chol      303 non-null    float64
#  5   fbs       303 non-null    float64
#  6   restecg   303 non-null    float64
#  7   thalach   303 non-null    float64
#  8   exang     303 non-null    float64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    float64
#  11  ca        303 non-null    object
#  12  thal      303 non-null    object
#  13  num       303 non-null    int64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 33.3+ KB

# %%
df['thalach']=df['thalach'].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    float64
#  1   sex       303 non-null    float64
#  2   cp        303 non-null    float64
#  3   trestbps  303 non-null    float64
#  4   chol      303 non-null    float64
#  5   fbs       303 non-null    float64
#  6   restecg   303 non-null    float64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    float64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    float64
#  11  ca        303 non-null    object
#  12  thal      303 non-null    object
#  13  num       303 non-null    int64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 33.3+ KB

# %%
df.shape
# Out:
# (303, 14)

# %%
df.size
# Out:
# 4242

# %%
s=df.groupby(["sex","chol"]).size()
s
# Out:
# sex  chol
# 0.0  141.0    1
#      149.0    1
#      160.0    1
#      164.0    1
#      177.0    1
#              ..
# 1.0  325.0    1
#      326.0    1
#      330.0    1
#      335.0    2
#      353.0    1
# Length: 199, dtype: int64

# %%
import numpy as np   #.values convert data into array
male=df["sex"].values
unique,count_values=np.unique(male,return_counts=True)
print(f'Female:{count_values[0]}')
print(f'Male:{count_values[1]}')
# Out:
# Female:97
# Male:206

# %%
s=df.head(25)

# %%
import seaborn as sns
sns.catplot(x='sex',hue='chol',kind='count',data=s)

# %%
x=df.iloc[:,[0,1]].values
x
# Out:
# array([[63.,  1.],
#        [67.,  1.],
#        [67.,  1.],
#        [37.,  1.],
#        [41.,  0.],
#        [56.,  1.],
#        [62.,  0.],
#        [57.,  0.],
#        [63.,  1.],
#        [53.,  1.],
#        [57.,  1.],
#        [56.,  0.],
#        [56.,  1.],
#        [44.,  1.],
#        [52.,  1.],
#        [57.,  1.],
#        [48.,  1.],
#        [54.,  1.],
#        [48.,  0.],
#        [49.,  1.],
#        [64.,  1.],
#        [58.,  0.],
#        [58.,  1.],
#        [58.,  1.],
#        [60.,  1.],
#        [50.,  0.],
#        [58.,  0.],
#        [66.,  0.],
#        [43.,  1.],
#        [40.,  1.],
#        [69.,  0.],
#        [60.,  1.],
#        [64.,  1.],
#        [59.,  1.],
#        [44.,  1.],
#        [42.,  1.],
#        [43.,  1.],
#        [57.,  1.],
#        [55.,  1.],
#        [61.,  1.],
#        [65.,  0.],
#        [40.,  1.],
#        [71.,  0.],
#        [59.,  1.],
#        [61.,  0.],
#        [58.,  1.],
#        [51.,  1.],
# ...

# %%
y=df.iloc[:,2].values #analysing chest pain in every person
y
# Out:
# array([1., 4., 4., 3., 2., 2., 4., 4., 4., 4., 4., 2., 3., 2., 3., 3., 2.,
#        4., 3., 2., 1., 1., 2., 3., 4., 3., 3., 1., 4., 4., 1., 4., 3., 4.,
#        3., 4., 4., 4., 4., 3., 4., 1., 2., 3., 4., 3., 3., 4., 3., 3., 2.,
#        4., 4., 2., 4., 4., 3., 4., 3., 1., 4., 3., 4., 3., 4., 4., 3., 3.,
#        4., 3., 3., 4., 4., 4., 4., 3., 4., 3., 2., 4., 4., 4., 3., 3., 2.,
#        3., 3., 3., 4., 3., 4., 4., 3., 3., 3., 4., 4., 4., 2., 4., 4., 1.,
#        4., 3., 3., 2., 4., 3., 4., 4., 4., 4., 1., 4., 3., 2., 3., 4., 4.,
#        4., 4., 4., 3., 4., 1., 2., 4., 4., 2., 4., 3., 3., 2., 4., 3., 2.,
#        4., 2., 4., 3., 2., 1., 2., 3., 3., 3., 4., 3., 2., 3., 1., 4., 3.,
#        4., 4., 4., 4., 4., 4., 3., 2., 4., 3., 4., 3., 4., 3., 2., 4., 2.,
#        3., 4., 4., 4., 4., 4., 4., 4., 3., 3., 4., 4., 1., 1., 4., 2., 3.,
#        2., 2., 3., 3., 4., 4., 4., 3., 4., 1., 4., 2., 1., 4., 4., 3., 3.,
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
print(x)
print(x_train)
print(x_test)
# Out:
# [[63.  1.]
#  [67.  1.]
#  [67.  1.]
#  [37.  1.]
#  [41.  0.]
#  [56.  1.]
#  [62.  0.]
#  [57.  0.]
#  [63.  1.]
#  [53.  1.]
#  [57.  1.]
#  [56.  0.]
#  [56.  1.]
#  [44.  1.]
#  [52.  1.]
#  [57.  1.]
#  [48.  1.]
#  [54.  1.]
#  [48.  0.]
#  [49.  1.]
#  [64.  1.]
#  [58.  0.]
#  [58.  1.]
#  [58.  1.]
#  [60.  1.]
#  [50.  0.]
#  [58.  0.]
#  [66.  0.]
#  [43.  1.]
#  [40.  1.]
#  [69.  0.]
#  [60.  1.]
#  [64.  1.]
#  [59.  1.]
#  [44.  1.]
#  [42.  1.]
#  [43.  1.]
#  [57.  1.]
#  [55.  1.]
#  [61.  1.]
#  [65.  0.]
#  [40.  1.]
#  [71.  0.]
#  [59.  1.]
#  [61.  0.]
#  [58.  1.]
#  [51.  1.]
#  [50.  1.]
#  [65.  0.]
#  [53.  1.]
#  [41.  0.]
#  [65.  1.]
#  [44.  1.]
#  [44.  1.]
#  [60.  1.]
#  [54.  1.]
#  [50.  1.]
#  [41.  1.]
#  [54.  1.]
#  [51.  1.]
#  [51.  0.]
#  [46.  0.]
#  [58.  1.]
#  [54.  0.]
#  [54.  1.]
#  [60.  1.]
#  [60.  1.]
#  [54.  1.]
#  [59.  1.]
#  [46.  1.]
#  [65.  0.]
#  [67.  1.]
#  [62.  1.]
#  [65.  1.]
#  [44.  1.]
#  [65.  0.]
# ...

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (212, 2)
# (91, 2)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (212,)
# (91,)

# %%
from sklearn.linear_model import LinearRegression 
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
# array([[34.,  0.],
#        [67.,  0.],
#        [54.,  1.],
#        [64.,  0.],
#        [44.,  1.],
#        [67.,  1.],
#        [57.,  1.],
#        [35.,  1.],
#        [53.,  1.],
#        [46.,  0.],
#        [56.,  1.],
#        [55.,  0.],
#        [64.,  0.],
#        [56.,  1.],
#        [57.,  1.],
#        [60.,  1.],
#        [60.,  0.],
#        [66.,  1.],
#        [50.,  0.],
#        [71.,  0.],
#        [58.,  1.],
#        [41.,  1.],
#        [47.,  1.],
#        [61.,  1.],
#        [51.,  1.],
#        [46.,  0.],
#        [64.,  1.],
#        [61.,  1.],
#        [64.,  1.],
#        [54.,  1.],
#        [68.,  0.],
#        [42.,  0.],
#        [43.,  0.],
#        [63.,  1.],
#        [58.,  1.],
#        [41.,  0.],
#        [41.,  1.],
#        [53.,  0.],
#        [52.,  1.],
#        [54.,  0.],
#        [56.,  1.],
#        [51.,  1.],
#        [62.,  1.],
#        [59.,  1.],
#        [44.,  1.],
#        [47.,  1.],
#        [58.,  1.],
# ...

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([2.97984432, 3.31763683, 3.14009317, 3.28692842, 3.0377318 ,
#        3.27316295, 3.17080158, 2.94560657, 3.12985703, 3.10267796,
#        3.16056544, 3.19480319, 3.28692842, 3.16056544, 3.17080158,
#        3.20150999, 3.24598388, 3.26292681, 3.14362251, 3.35858138,
#        3.18103772, 3.00702339, 3.06844021, 3.21174613, 3.10938476,
#        3.10267796, 3.24245454, 3.21174613, 3.24245454, 3.14009317,
#        3.32787297, 3.06173341, 3.07196955, 3.2322184 , 3.18103772,
#        3.05149728, 3.00702339, 3.17433092, 3.1196209 , 3.18456706,
#        3.16056544, 3.10938476, 3.22198226, 3.19127385, 3.0377318 ,
#        3.06844021, 3.18103772, 3.14009317, 3.18103772, 3.21527547,
#        3.18103772, 3.26645615, 3.10938476, 3.18456706, 3.25269067,
#        3.31763683, 3.17080158, 2.97631498, 3.2255116 , 3.21174613,
#        3.15385865, 3.0377318 , 3.15032931, 3.14009317, 3.19127385,
#        3.18103772, 3.2255116 , 3.16056544, 3.20503933, 3.25269067,
# ...

# %%
model.predict([[67.,  1.]])
# Out:
# array([3.27316295])

# %%
plt.scatter(y_pred,y_test,color='b',label="Analysis of heart rate")
plt.xlabel("predicted value of chest pain")
plt.ylabel("tested value")
plt.legend()

# %%
#if we want to check the actual chest pain accuracy
import seaborn as sns
sns.catplot(x='sex',hue='cp',kind='count',data=df)

# %%
plt.bar(df["age"],df["restecg"])
plt.xlabel("Age")
plt.ylabel("ECG")
plt.title("Heart disease variation wrt ECG")
# Out:
# Text(0.5, 1.0, 'Heart disease variation wrt ECG')

# %%
import seaborn as sns
x=sns.catplot(x='sex',hue='fbs',kind='count',data=df)
x.set(title="Heart disease variation wrt fasting blood sugar")

# %%
import seaborn as sns
x=sns.catplot(x='num',hue='thalach',kind='count',data=df)
x.set(title="Number of people having maximum heart rate")

# %%
plt.bar(df["age"],df["oldpeak"])
plt.xlabel("Age")
plt.ylabel("oldpeak")
plt.title("Depression induced by exercise relative to rest")
# Out:
# Text(0.5, 1.0, 'Depression induced by exercise relative to rest')
